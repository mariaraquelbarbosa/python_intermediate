# %% [markdown]
# # WRITING EFFICIENT CODE WITH PANDAS

# %% [markdown]
# ## CAPÍTULO 1: Selecionando linhas e colunas de forma eficiente

# %% [markdown]
# O Pandas tem como função: **otimizar a realização de tarefas dentro do código Python.**
#
# Para comprovar isso, ao longo do resumo utilizaremos da função **`time`** do pacote **`time`** que irá medir o tempo de execução dos códigos.

# %% [markdown]
# ### time.time( )

# %%
import time
#registro do tempo antes da execução do código
start_time=time.time()

#execute a operação 
def is_divisible(x, y):
    if x % y == 0:
        return True
    else:
        return False 
is_divisible(17316,0.3)

#registro do tempo depois da execução do código
end_time=time.time()

print("O resultado foi calculado em {:.6f} segundos".format(end_time-start_time))
# Out:
# O resultado foi calculado em 0.001000 segundos

# %% [markdown]
# ## iloc[ ] e loc[ ]

# %% [markdown]
# **loc[ ]**: selecionar linhas em específico a partir do nome do índice
#
# **iloc[ ]**:selecionar linhas em específico a partir do número do índice

# %%
import pandas as pd
#vamos utilizar de uma base de dados retirada do keggle que traz dados sobre o cátalogo da netflix no ano de 2021
data = pd.read_csv("netflix1.csv")
data.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# 2                 TV Dramas, TV Horror, TV Mysteries
# 3                 Children & Family Movies, Comedies
# 4   Dramas, Independent Movies, International Movies

# %% [markdown]
# ### Vamos começar pelo loc [ ]

# %%
#a função loc irá selecionar somente a linha chamada através do nome do índice, nesse caso, os números de forma crescente.
data.loc[0]
# Out:
# show_id                           s1
# type                           Movie
# title           Dick Johnson Is Dead
# director             Kirsten Johnson
# country                United States
# date_added                 9/25/2021
# release_year                    2020
# rating                         PG-13
# duration                      90 min
# listed_in              Documentaries
# Name: 0, dtype: object

# %%
#podemos utilizar um intervalo para selecionar um grupo de linhas
data.loc[0:2]
# Out:
#   show_id     type                 title         director        country  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson  United States
# 1      s3  TV Show             Ganglands  Julien Leclercq         France
# 2      s6  TV Show         Midnight Mass    Mike Flanagan  United States
#
#   date_added  release_year rating  duration  \
# 0  9/25/2021          2020  PG-13    90 min
# 1  9/24/2021          2021  TV-MA  1 Season
# 2  9/24/2021          2021  TV-MA  1 Season
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# 2                 TV Dramas, TV Horror, TV Mysteries

# %% [markdown]
# ### E se quisermos o resultado em forma de DataFrame?

# %%
#basta colocar só mais 1 par de colchetes
data.loc[[0]]
# Out:
#   show_id   type                 title         director        country  \
# 0      s1  Movie  Dick Johnson Is Dead  Kirsten Johnson  United States
#
#   date_added  release_year rating duration      listed_in
# 0  9/25/2021          2020  PG-13   90 min  Documentaries

# %%
# para localizar mais de uma linha basta acrescentar dentro dos colchetes o índice desejado
data.loc[[0,19,2]]
# Out:
#    show_id     type                 title                      director  \
# 0       s1    Movie  Dick Johnson Is Dead               Kirsten Johnson
# 19   s3232    Movie   True: Winter Wishes  Mark Thornton, Todd Kauffman
# 2       s6  TV Show         Midnight Mass                 Mike Flanagan
#
#           country  date_added  release_year rating  duration  \
# 0   United States   9/25/2021          2020  PG-13    90 min
# 19  United States  11/26/2019          2019   TV-Y    46 min
# 2   United States   9/24/2021          2021  TV-MA  1 Season
#
#                              listed_in
# 0                        Documentaries
# 19            Children & Family Movies
# 2   TV Dramas, TV Horror, TV Mysteries

# %% [markdown]
# ### Agora o iloc[ ]

# %%
#ele permite fazer a filtragem através da posição da linha no DataFrame
#nesse caso a posição das linhas corresponde ao mesmo nome das linhas
data.iloc[[1,7,3]]
# Out:
#   show_id     type                             title         director country  \
# 1      s3  TV Show                         Ganglands  Julien Leclercq  France
# 7    s939    Movie   Motu Patlu in the Game of Zones      Suhas Kadav   India
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti  Brazil
#
#   date_added  release_year rating  duration  \
# 1  9/24/2021          2021  TV-MA  1 Season
# 7   5/1/2021          2019  TV-Y7    87 min
# 3  9/22/2021          2021  TV-PG    91 min
#
#                                            listed_in
# 1  Crime TV Shows, International TV Shows, TV Act...
# 7  Children & Family Movies, Comedies, Music & Mu...
# 3                 Children & Family Movies, Comedies

# %%
#por intervalo
data.iloc[3092:3095]
# Out:
#      show_id   type                                 title         director  \
# 3092   s4225  Movie                      Puriyatha Puthir  Ranjit Jeyakodi
# 3093   s4226  Movie                              Taramani              Ram
# 3094   s4243  Movie  Taylor Swift reputation Stadium Tour     Paul Dugdale
#
#              country  date_added  release_year rating duration  \
# 3092           India    1/1/2019          2017  TV-MA  120 min
# 3093           India    1/1/2019          2017  TV-MA  148 min
# 3094  United Kingdom  12/31/2018          2018  TV-PG  125 min
#
#                                              listed_in
# 3092                   International Movies, Thrillers
# 3093  Dramas, Independent Movies, International Movies
# 3094                                  Music & Musicals

# %% [markdown]
# ### LOC x ILOC: quem ganha na eficiência?

# %%
#loc
rows=range(0,8000)
loc_start_time=time.time()
data.loc[rows]
loc_end_time=time.time()
print('{}'.format(loc_end_time-loc_start_time))
# Out:
# 0.0060002803802490234

# %%
#iloc
rows=range(0,8000)
iloc_start_time=time.time()
data.iloc[rows]
iloc_end_time=time.time()
print('{}'.format(iloc_end_time-iloc_start_time))
# Out:
# 0.00500035285949707

# %%
#diferença de velocidade:
print('a diferença é de: {:.4} %'.format(((loc_end_time-loc_start_time)-(iloc_end_time-iloc_start_time))/(iloc_end_time-iloc_start_time)*100))
print('Conclusão: Como o iloc[ ] aproveita a ordem dos índices que já são ordenados, ele é portanto mais rápido.')
# Out:
# a diferença é de: 20.0 %
# Conclusão: Como o iloc[ ] aproveita a ordem dos índices que já são ordenados, ele é portanto mais rápido.

# %% [markdown]
# # Outras funções...

# %% [markdown]
# ### Para selecionar colunas pelo nome:

# %%
#para selecionar a coluna por nome, basta adicionar colchetes duplos
data[['title','country','type']]
#atenção este não é a forma mais eficiente!
# Out:
#                                                   title         country  \
# 0                                  Dick Johnson Is Dead   United States
# 1                                             Ganglands          France
# 2                                         Midnight Mass   United States
# 3                      Confessions of an Invisible Girl          Brazil
# 4                                               Sankofa   United States
# 5                         The Great British Baking Show  United Kingdom
# 6                                          The Starling   United States
# 7                       Motu Patlu in the Game of Zones           India
# 8                                          Je Suis Karl         Germany
# 9                              Motu Patlu in Wonderland           India
# 10                       Motu Patlu: Deep Sea Adventure           India
# 11                             Motu Patlu: Mission Moon           India
# 12                                     99 Songs (Tamil)        Pakistan
# 13                          Bridgerton - The Afterparty   United States
# 14                        Bling Empire - The Afterparty   United States
# 15                           Cobra Kai - The Afterparty   United States
# 16                          The Circle - The Afterparty   United States
# 17                                Jailbirds New Orleans        Pakistan
# 18                      Crime Stories: India Detectives        Pakistan
# 19                                  True: Winter Wishes   United States
# 20                                True: Magical Friends   United States
# 21                               True: Wonderful Wishes   United States
# 22                               Dance & Sing with True   United States
# 23                     My Little Pony: A New Generation       Not Given
# 24                                     Bangkok Breaking       Not Given
# 25    Europe's Most Dangerous Man: Otto Skorzeny in ...       Not Given
# 26                                      Samudri Lootere       Not Given
# 27      Monsters Inside: The 24 Faces of Billy Milligan   United States
# 28         Go! Go! Cory Carson: Chrissy Takes the Wheel   United States
# 29                                                Jeans           India
# ...                                                 ...             ...
# 8760                                            Trotsky          Russia
# 8761                                         Twin Peaks   United States
# 8762                                         Twirlywoos  United Kingdom
# 8763                        Twisted Trunk, Big Fat Body           India
# 8764                                      Ugly Duckling        Thailand
# 8765                                      V.R. Troopers   United States
# 8766                                            Vroomiz     South Korea
# 8767                                  Wartime Portraits          Poland
# 8768                                              Weeds   United States
# 8769                         Weird Wonders of the World  United Kingdom
# 8770                          What Happens to My Family          Turkey
# 8771                                    Timeless Season        Pakistan
# 8772                                      What Is Love?          Taiwan
# 8773                               When Calls the Heart   United States
# 8774                                      Who's the One          Taiwan
# 8775                                        Wild Alaska  United Kingdom
# 8776                                        Wild Arabia  United Kingdom
# 8777                                          Winsanity   United States
# 8778                                         Winter Sun          Turkey
# 8779                                  Women Behind Bars   United States
# 8780                             World's Busiest Cities  United Kingdom
# 8781                                    Yeh Meri Family           India
# 8782                                       Yo-Kai Watch   United States
# 8783                               Yoko and His Friends          Russia
# 8784                                    Yu-Gi-Oh! Arc-V           Japan
# 8785                                         Yunus Emre          Turkey
# 8786                                          Zak Storm   United States
# 8787                                 Zindagi Gulzar Hai        Pakistan
# 8788                                               Yoko        Pakistan
# 8789                                                YOM        Pakistan
#
#          type
# 0       Movie
# 1     TV Show
# 2     TV Show
# 3       Movie
# 4       Movie
# 5     TV Show
# 6       Movie
# 7       Movie
# 8       Movie
# 9       Movie
# 10      Movie
# 11      Movie
# 12      Movie
# 13      Movie
# 14      Movie
# 15      Movie
# 16      Movie
# 17    TV Show
# 18    TV Show
# 19      Movie
# 20    TV Show
# 21    TV Show
# 22    TV Show
# 23      Movie
# 24    TV Show
# 25      Movie
# 26      Movie
# 27    TV Show
# 28      Movie
# 29      Movie
# ...       ...
# 8760  TV Show
# 8761  TV Show
# 8762  TV Show
# 8763    Movie
# 8764  TV Show
# 8765  TV Show
# 8766  TV Show
# 8767  TV Show
# 8768  TV Show
# 8769  TV Show
# 8770  TV Show
# 8771  TV Show
# 8772  TV Show
# 8773  TV Show
# 8774  TV Show
# 8775  TV Show
# 8776  TV Show
# 8777  TV Show
# 8778  TV Show
# 8779  TV Show
# 8780  TV Show
# 8781  TV Show
# 8782  TV Show
# 8783    Movie
# 8784  TV Show
# 8785  TV Show
# 8786  TV Show
# 8787  TV Show
# 8788  TV Show
# 8789  TV Show
#
# [8790 rows x 3 columns]

# %% [markdown]
# ### Através da função Iloc[ ] é possivel selecionar uma ou várias colunas pelo nome de forma mais eficiente.

# %% [markdown]
# **A sintaxe do iloc para esse propósito é simples:**
#
# -denotamos com dois pontos(:) todas as linhas que queremos do DataFrame
#
# -e depois da vírgula, usamos dois pontos(:) seguido do número que representa até que coluna queremos

# %%
data.iloc[:,:5]
# Out:
#      show_id     type                                              title  \
# 0         s1    Movie                               Dick Johnson Is Dead
# 1         s3  TV Show                                          Ganglands
# 2         s6  TV Show                                      Midnight Mass
# 3        s14    Movie                   Confessions of an Invisible Girl
# 4         s8    Movie                                            Sankofa
# 5         s9  TV Show                      The Great British Baking Show
# 6        s10    Movie                                       The Starling
# 7       s939    Movie                    Motu Patlu in the Game of Zones
# 8        s13    Movie                                       Je Suis Karl
# 9       s940    Movie                           Motu Patlu in Wonderland
# 10      s941    Movie                     Motu Patlu: Deep Sea Adventure
# 11      s942    Movie                           Motu Patlu: Mission Moon
# 12      s852    Movie                                   99 Songs (Tamil)
# 13      s471    Movie                        Bridgerton - The Afterparty
# 14      s730    Movie                      Bling Empire - The Afterparty
# 15      s731    Movie                         Cobra Kai - The Afterparty
# 16      s913    Movie                        The Circle - The Afterparty
# 17        s4  TV Show                              Jailbirds New Orleans
# 18       s15  TV Show                    Crime Stories: India Detectives
# 19     s3232    Movie                                True: Winter Wishes
# 20     s4832  TV Show                              True: Magical Friends
# 21     s4833  TV Show                             True: Wonderful Wishes
# 22     s4857  TV Show                             Dance & Sing with True
# 23        s7    Movie                   My Little Pony: A New Generation
# 24       s12  TV Show                                   Bangkok Breaking
# 25       s17    Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 26     s7930    Movie                                    Samudri Lootere
# 27       s21  TV Show    Monsters Inside: The 24 Faces of Billy Milligan
# 28       s24    Movie       Go! Go! Cory Carson: Chrissy Takes the Wheel
# 29       s25    Movie                                              Jeans
# ...      ...      ...                                                ...
# 8760   s8634  TV Show                                            Trotsky
# 8761   s8645  TV Show                                         Twin Peaks
# 8762   s8647  TV Show                                         Twirlywoos
# 8763   s8648    Movie                        Twisted Trunk, Big Fat Body
# 8764   s8654  TV Show                                      Ugly Duckling
# 8765   s8670  TV Show                                      V.R. Troopers
# 8766   s8685  TV Show                                            Vroomiz
# 8767   s8701  TV Show                                  Wartime Portraits
# 8768   s8711  TV Show                                              Weeds
# 8769   s8713  TV Show                         Weird Wonders of the World
# 8770   s8721  TV Show                          What Happens to My Family
# 8771   s8593  TV Show                                    Timeless Season
# 8772   s8722  TV Show                                      What Is Love?
# 8773   s8727  TV Show                               When Calls the Heart
# 8774   s8737  TV Show                                      Who's the One
# 8775   s8741  TV Show                                        Wild Alaska
# 8776   s8742  TV Show                                        Wild Arabia
# 8777   s8748  TV Show                                          Winsanity
# 8778   s8750  TV Show                                         Winter Sun
# 8779   s8756  TV Show                                  Women Behind Bars
# 8780   s8759  TV Show                             World's Busiest Cities
# 8781   s8776  TV Show                                    Yeh Meri Family
# 8782   s8781  TV Show                                       Yo-Kai Watch
# 8783   s8785    Movie                               Yoko and His Friends
# 8784   s8796  TV Show                                    Yu-Gi-Oh! Arc-V
# 8785   s8797  TV Show                                         Yunus Emre
# 8786   s8798  TV Show                                          Zak Storm
# 8787   s8801  TV Show                                 Zindagi Gulzar Hai
# 8788   s8784  TV Show                                               Yoko
# 8789   s8786  TV Show                                                YOM
#
#                                            director         country
# 0                                   Kirsten Johnson   United States
# 1                                   Julien Leclercq          France
# 2                                     Mike Flanagan   United States
# 3                                     Bruno Garotti          Brazil
# 4                                      Haile Gerima   United States
# 5                                   Andy Devonshire  United Kingdom
# 6                                    Theodore Melfi   United States
# 7                                       Suhas Kadav           India
# 8                               Christian Schwochow         Germany
# 9                                       Suhas Kadav           India
# 10                                      Suhas Kadav           India
# 11                                      Suhas Kadav           India
# 12                                        Not Given        Pakistan
# 13                  Krysia Plonka, Kristian Mercado   United States
# 14                  Krysia Plonka, Kristian Mercado   United States
# 15                  Krysia Plonka, Kristian Mercado   United States
# 16                  Krysia Plonka, Kristian Mercado   United States
# 17                                        Not Given        Pakistan
# 18                                        Not Given        Pakistan
# 19                     Mark Thornton, Todd Kauffman   United States
# 20                     Mark Thornton, Todd Kauffman   United States
# 21                     Mark Thornton, Todd Kauffman   United States
# 22                     Mark Thornton, Todd Kauffman   United States
# 23                    Robert Cullen, José Luis Ucha       Not Given
# 24                                Kongkiat Komesiri       Not Given
# 25    Pedro de Echave García, Pablo Azorín Williams       Not Given
# 26                                 Anirban Majumder       Not Given
# 27                                  Olivier Megaton   United States
# 28                          Alex Woo, Stanley Moore   United States
# 29                                       S. Shankar           India
# ...                                             ...             ...
# 8760                                      Not Given          Russia
# 8761                                      Not Given   United States
# 8762                                      Not Given  United Kingdom
# 8763                                      Not Given           India
# 8764                                      Not Given        Thailand
# 8765                                      Not Given   United States
# 8766                                      Not Given     South Korea
# 8767                                      Not Given          Poland
# 8768                                      Not Given   United States
# 8769                                      Not Given  United Kingdom
# 8770                                      Not Given          Turkey
# 8771                                      Not Given        Pakistan
# 8772                                      Not Given          Taiwan
# 8773                                      Not Given   United States
# 8774                                      Not Given          Taiwan
# 8775                                      Not Given  United Kingdom
# 8776                                      Not Given  United Kingdom
# 8777                                      Not Given   United States
# 8778                                      Not Given          Turkey
# 8779                                      Not Given   United States
# 8780                                      Not Given  United Kingdom
# 8781                                      Not Given           India
# 8782                                      Not Given   United States
# 8783                                      Not Given          Russia
# 8784                                      Not Given           Japan
# 8785                                      Not Given          Turkey
# 8786                                      Not Given   United States
# 8787                                      Not Given        Pakistan
# 8788                                      Not Given        Pakistan
# 8789                                      Not Given        Pakistan
#
# [8790 rows x 5 columns]

# %% [markdown]
# #### Conclusão: a função loc[  ] funciona melhor para selecionar colunas, enquanto, a função iloc[  ] é melhor para selecionar linhas específicas.

# %% [markdown]
# ## Selecionando aleatoriamente linhas e colunas de um DataFrame

# %% [markdown]
# ### Podemos utilizar o pacote Numpy

# %%
import numpy as np
nump_start_time=time.time()
data.iloc[np.random.randint(low=0, high=data.shape[0], size=6)]
#atenção essa não é a forma mais eficiente!
# Out:
#      show_id     type                  title        director        country  \
# 7968   s4744  TV Show  A Very Secret Service       Not Given         France
# 7017   s2945  TV Show  Who Killed Malcolm X?       Not Given  United States
# 3735   s5184    Movie              Mubarakan    Anees Bazmee          India
# 6982   s1642  TV Show   Sugar Rush Christmas       Not Given  United States
# 1261   s1348    Movie            Black Beach  Esteban Crespo          Spain
# 3476   s4803    Movie                    Zoo    Shlok Sharma          India
#
#       date_added  release_year rating   duration  \
# 7968   7/30/2018          2018  TV-MA  2 Seasons
# 7017    2/7/2020          2020  TV-MA   1 Season
# 3735   11/5/2017          2017  PG-13    153 min
# 6982  11/27/2020          2020  TV-14  2 Seasons
# 1261    2/3/2021          2020  TV-MA    116 min
# 3476    7/1/2018          2018  TV-MA     94 min
#
#                                              listed_in
# 7968               International TV Shows, TV Comedies
# 7017                        Crime TV Shows, Docuseries
# 3735            Comedies, Dramas, International Movies
# 6982                                        Reality TV
# 1261          Action & Adventure, International Movies
# 3476  Dramas, Independent Movies, International Movies

# %% [markdown]
# ### Podemos usar Pandas (mais eficiência)

# %% [markdown]
# #### Função:  .sample()

# %%
pandas_start_time=time.time()
data.sample(6,axis=0)
#denotamos quantas amostras queremos obter e o eixo do qual queremos amostrar
# Out:
#      show_id   type               title                          director  \
# 965     s927  Movie  Au coeur des gangs                Vondie Curtis-Hall
# 2049   s2532  Movie          Dilan 1990          Fajar Bustomi, Pidi Baiq
# 693     s506  Movie             Therapy  Anurin Nwunembom, Musing Derrick
# 4141   s5796  Movie   The White Helmets             Orlando von Einsiedel
# 1122   s1146  Movie  At Eternity's Gate                   Julian Schnabel
# 3776   s5257  Movie     Out of Thin Air                      Dylan Howitt
#
#              country date_added  release_year rating duration  \
# 965    United States   5/1/2021          2006      R   97 min
# 2049       Indonesia  5/14/2020          2018  TV-14  109 min
# 693        Not Given   7/7/2021          2020  TV-PG   85 min
# 4141  United Kingdom  9/16/2016          2016  TV-PG   41 min
# 1122         Ireland  3/31/2021          2018  PG-13  111 min
# 3776       Not Given  9/29/2017          2017  TV-MA   85 min
#
#                                           listed_in
# 965                      Action & Adventure, Dramas
# 2049  Dramas, International Movies, Romantic Movies
# 693                    Dramas, International Movies
# 4141                                  Documentaries
# 1122                                         Dramas
# 3776            Documentaries, International Movies

# %%
#diferença de velocidade:
print('a diferença é de: {:.4} %'.format(((time.time()-nump_start_time)-(time.time()-pandas_start_time))/(time.time()-pandas_start_time)*100))
print('Conclusão: utilizar Numpy para selecionar linhas e colunas aleatórias é menos eficiente do que usar a função .sample() do pacote pandas')
# Out:
# a diferença é de: 219.0 %
# Conclusão: utilizar Numpy para selecionar linhas e colunas aleatórias é menos eficiente do que usar a função .sample() do pacote pandas

# %% [markdown]
# ## CAPÍTULO 2: Replacing values in a DataFrame

# %% [markdown]
# ### Substituindo valores dentro do DataFrame:

# %%
#podemos usar o .loc[ ] 
import time
start_time = time.time()
data['country'].loc[data.country == 'United States'] = 'banana'
print("O tempo de excecução usando .loc[] é de {} segundos".format(time.time() - start_time))
data.head()
# Out:
# O tempo de excecução usando .loc[] é de 0.07360339164733887 segundos
# C:\ProgramData\anaconda\lib\site-packages\pandas\core\indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
#   show_id     type                             title         director country  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson  banana
# 1      s3  TV Show                         Ganglands  Julien Leclercq  France
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan  banana
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti  Brazil
# 4      s8    Movie                           Sankofa     Haile Gerima  banana
#
#   date_added  release_year rating  duration  \
# 0  9/25/2021          2020  PG-13    90 min
# 1  9/24/2021          2021  TV-MA  1 Season
# 2  9/24/2021          2021  TV-MA  1 Season
# 3  9/22/2021          2021  TV-PG    91 min
# 4  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# 2                 TV Dramas, TV Horror, TV Mysteries
# 3                 Children & Family Movies, Comedies
# 4   Dramas, Independent Movies, International Movies

# %% [markdown]
# ##### É a maneira mais eficiente? nãooo!!

# %% [markdown]
# ### Podemos usar a função:  .replace( )

# %%
start_time2= time.time()
data['listed_in'].replace('Documentaries','Documentario', inplace=True)
print("O tempo de excecução usando .replace() é de {:.6} segundos".format(time.time() - start_time2))

data.head()
# Out:
# O tempo de excecução usando .replace() é de 0.0176001 segundos
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                       Documentario
# 1  Crime TV Shows, International TV Shows, TV Act...
# 2                 TV Dramas, TV Horror, TV Mysteries
# 3                 Children & Family Movies, Comedies
# 4   Dramas, Independent Movies, International Movies

# %%
print('A diferença de tempo entre usar replace e não usar é de {:.4}% '.format(((time.time()-start_time)-(time.time()-start_time2))/(time.time()-start_time2)*100))
print('ou de {:.6} segundos'.format((time.time() - start_time)-(time.time() - start_time2)))
print('então é bom usar!')
# Out:
# A diferença de tempo entre usar replace e não usar é de 981.3%
# ou de 64.3845 segundos
# então é bom usar!

# %% [markdown]
# ## E se quisermos substituir vários valores ao mesmo tempo??

# %% [markdown]
# ### utilizaremos o conceito de listas junto a função  `.replace( )`

# %%
data['type'].replace(['Movie','TV Show'],'netflix', inplace=True)
data.head()
# Out:
#   show_id     type                             title         director country  \
# 0      s1  netflix              Dick Johnson Is Dead  Kirsten Johnson  banana
# 1      s3  netflix                         Ganglands  Julien Leclercq  France
# 2      s6  netflix                     Midnight Mass    Mike Flanagan  banana
# 3     s14  netflix  Confessions of an Invisible Girl    Bruno Garotti  Brazil
# 4      s8  netflix                           Sankofa     Haile Gerima  banana
#
#   date_added  release_year rating  duration  \
# 0  9/25/2021          2020  PG-13    90 min
# 1  9/24/2021          2021  TV-MA  1 Season
# 2  9/24/2021          2021  TV-MA  1 Season
# 3  9/22/2021          2021  TV-PG    91 min
# 4  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# 2                 TV Dramas, TV Horror, TV Mysteries
# 3                 Children & Family Movies, Comedies
# 4   Dramas, Independent Movies, International Movies

# %% [markdown]
# caso queiramos substituir simultaneamente vários índices por valores distintos entre si (cada entrada com uma saída diferente):

# %%
data['country'].replace(['banana','Brazil','France'],['hamburguer','penta','croissant'], inplace=True)
data.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1  netflix              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  netflix                         Ganglands  Julien Leclercq
# 2      s6  netflix                     Midnight Mass    Mike Flanagan
# 3     s14  netflix  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8  netflix                           Sankofa     Haile Gerima
#
#       country date_added  release_year rating  duration  \
# 0  hamburguer  9/25/2021          2020  PG-13    90 min
# 1   croissant  9/24/2021          2021  TV-MA  1 Season
# 2  hamburguer  9/24/2021          2021  TV-MA  1 Season
# 3       penta  9/22/2021          2021  TV-PG    91 min
# 4  hamburguer  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# 2                 TV Dramas, TV Horror, TV Mysteries
# 3                 Children & Family Movies, Comedies
# 4   Dramas, Independent Movies, International Movies

# %% [markdown]
# ## E se quisermos usar um método mais eficiente do que o método mais eficiente que vimos acima?

# %% [markdown]
# ### Usamos os dicionários!!

# %%
# em geral trabalhar com dicionários é muito mais eficiente do que trabalhar com listas

# %%
data.replace({'country':{'hamburguer':'United States', 'croissant':'France','penta':'Brazil'}})
# Out:
#      show_id     type                                              title  \
# 0         s1  netflix                               Dick Johnson Is Dead
# 1         s3  netflix                                          Ganglands
# 2         s6  netflix                                      Midnight Mass
# 3        s14  netflix                   Confessions of an Invisible Girl
# 4         s8  netflix                                            Sankofa
# 5         s9  netflix                      The Great British Baking Show
# 6        s10  netflix                                       The Starling
# 7       s939  netflix                    Motu Patlu in the Game of Zones
# 8        s13  netflix                                       Je Suis Karl
# 9       s940  netflix                           Motu Patlu in Wonderland
# 10      s941  netflix                     Motu Patlu: Deep Sea Adventure
# 11      s942  netflix                           Motu Patlu: Mission Moon
# 12      s852  netflix                                   99 Songs (Tamil)
# 13      s471  netflix                        Bridgerton - The Afterparty
# 14      s730  netflix                      Bling Empire - The Afterparty
# 15      s731  netflix                         Cobra Kai - The Afterparty
# 16      s913  netflix                        The Circle - The Afterparty
# 17        s4  netflix                              Jailbirds New Orleans
# 18       s15  netflix                    Crime Stories: India Detectives
# 19     s3232  netflix                                True: Winter Wishes
# 20     s4832  netflix                              True: Magical Friends
# 21     s4833  netflix                             True: Wonderful Wishes
# 22     s4857  netflix                             Dance & Sing with True
# 23        s7  netflix                   My Little Pony: A New Generation
# 24       s12  netflix                                   Bangkok Breaking
# 25       s17  netflix  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 26     s7930  netflix                                    Samudri Lootere
# 27       s21  netflix    Monsters Inside: The 24 Faces of Billy Milligan
# 28       s24  netflix       Go! Go! Cory Carson: Chrissy Takes the Wheel
# 29       s25  netflix                                              Jeans
# ...      ...      ...                                                ...
# 8760   s8634  netflix                                            Trotsky
# 8761   s8645  netflix                                         Twin Peaks
# 8762   s8647  netflix                                         Twirlywoos
# 8763   s8648  netflix                        Twisted Trunk, Big Fat Body
# 8764   s8654  netflix                                      Ugly Duckling
# 8765   s8670  netflix                                      V.R. Troopers
# 8766   s8685  netflix                                            Vroomiz
# 8767   s8701  netflix                                  Wartime Portraits
# 8768   s8711  netflix                                              Weeds
# 8769   s8713  netflix                         Weird Wonders of the World
# 8770   s8721  netflix                          What Happens to My Family
# 8771   s8593  netflix                                    Timeless Season
# 8772   s8722  netflix                                      What Is Love?
# 8773   s8727  netflix                               When Calls the Heart
# 8774   s8737  netflix                                      Who's the One
# 8775   s8741  netflix                                        Wild Alaska
# 8776   s8742  netflix                                        Wild Arabia
# 8777   s8748  netflix                                          Winsanity
# 8778   s8750  netflix                                         Winter Sun
# 8779   s8756  netflix                                  Women Behind Bars
# 8780   s8759  netflix                             World's Busiest Cities
# 8781   s8776  netflix                                    Yeh Meri Family
# 8782   s8781  netflix                                       Yo-Kai Watch
# 8783   s8785  netflix                               Yoko and His Friends
# 8784   s8796  netflix                                    Yu-Gi-Oh! Arc-V
# 8785   s8797  netflix                                         Yunus Emre
# 8786   s8798  netflix                                          Zak Storm
# 8787   s8801  netflix                                 Zindagi Gulzar Hai
# 8788   s8784  netflix                                               Yoko
# 8789   s8786  netflix                                                YOM
#
#                                            director         country  \
# 0                                   Kirsten Johnson   United States
# 1                                   Julien Leclercq          France
# 2                                     Mike Flanagan   United States
# 3                                     Bruno Garotti          Brazil
# 4                                      Haile Gerima   United States
# 5                                   Andy Devonshire  United Kingdom
# 6                                    Theodore Melfi   United States
# 7                                       Suhas Kadav           India
# 8                               Christian Schwochow         Germany
# 9                                       Suhas Kadav           India
# 10                                      Suhas Kadav           India
# 11                                      Suhas Kadav           India
# 12                                        Not Given        Pakistan
# 13                  Krysia Plonka, Kristian Mercado   United States
# 14                  Krysia Plonka, Kristian Mercado   United States
# 15                  Krysia Plonka, Kristian Mercado   United States
# 16                  Krysia Plonka, Kristian Mercado   United States
# 17                                        Not Given        Pakistan
# 18                                        Not Given        Pakistan
# 19                     Mark Thornton, Todd Kauffman   United States
# 20                     Mark Thornton, Todd Kauffman   United States
# 21                     Mark Thornton, Todd Kauffman   United States
# 22                     Mark Thornton, Todd Kauffman   United States
# 23                    Robert Cullen, José Luis Ucha       Not Given
# 24                                Kongkiat Komesiri       Not Given
# 25    Pedro de Echave García, Pablo Azorín Williams       Not Given
# 26                                 Anirban Majumder       Not Given
# 27                                  Olivier Megaton   United States
# 28                          Alex Woo, Stanley Moore   United States
# 29                                       S. Shankar           India
# ...                                             ...             ...
# 8760                                      Not Given          Russia
# 8761                                      Not Given   United States
# 8762                                      Not Given  United Kingdom
# 8763                                      Not Given           India
# 8764                                      Not Given        Thailand
# 8765                                      Not Given   United States
# 8766                                      Not Given     South Korea
# 8767                                      Not Given          Poland
# 8768                                      Not Given   United States
# 8769                                      Not Given  United Kingdom
# 8770                                      Not Given          Turkey
# 8771                                      Not Given        Pakistan
# 8772                                      Not Given          Taiwan
# 8773                                      Not Given   United States
# 8774                                      Not Given          Taiwan
# 8775                                      Not Given  United Kingdom
# 8776                                      Not Given  United Kingdom
# 8777                                      Not Given   United States
# 8778                                      Not Given          Turkey
# 8779                                      Not Given   United States
# 8780                                      Not Given  United Kingdom
# 8781                                      Not Given           India
# 8782                                      Not Given   United States
# 8783                                      Not Given          Russia
# 8784                                      Not Given           Japan
# 8785                                      Not Given          Turkey
# 8786                                      Not Given   United States
# 8787                                      Not Given        Pakistan
# 8788                                      Not Given        Pakistan
# 8789                                      Not Given        Pakistan
#
#       date_added  release_year rating   duration  \
# 0      9/25/2021          2020  PG-13     90 min
# 1      9/24/2021          2021  TV-MA   1 Season
# 2      9/24/2021          2021  TV-MA   1 Season
# 3      9/22/2021          2021  TV-PG     91 min
# 4      9/24/2021          1993  TV-MA    125 min
# 5      9/24/2021          2021  TV-14  9 Seasons
# 6      9/24/2021          2021  PG-13    104 min
# 7       5/1/2021          2019  TV-Y7     87 min
# 8      9/23/2021          2021  TV-MA    127 min
# 9       5/1/2021          2013  TV-Y7     76 min
# 10      5/1/2021          2014  TV-Y7     76 min
# 11      5/1/2021          2013  TV-Y7     71 min
# 12     5/21/2021          2021  TV-14    131 min
# 13     7/13/2021          2021  TV-14     39 min
# 14     6/12/2021          2021  TV-MA     36 min
# 15     6/12/2021          2021  TV-MA     34 min
# 16      5/7/2021          2021  TV-14     35 min
# 17     9/24/2021          2021  TV-MA   1 Season
# 18     9/22/2021          2021  TV-MA   1 Season
# 19    11/26/2019          2019   TV-Y     46 min
# 20     6/15/2018          2018   TV-Y   1 Season
# 21     6/15/2018          2018   TV-Y   1 Season
# 22     5/18/2018          2018   TV-Y   1 Season
# 23     9/24/2021          2021     PG     91 min
# 24     9/23/2021          2021  TV-MA   1 Season
# 25     9/22/2021          2020  TV-MA     67 min
# 26     6/18/2019          2018   TV-Y     65 min
# 27     9/22/2021          2021  TV-14   1 Season
# 28     9/21/2021          2021   TV-Y     61 min
# 29     9/21/2021          1998  TV-14    166 min
# ...          ...           ...    ...        ...
# 8760  12/10/2018          2017  TV-MA   1 Season
# 8761    7/1/2017          1990  TV-14  2 Seasons
# 8762   5/15/2020          2018   TV-Y  2 Seasons
# 8763   1/15/2017          2015  TV-14     89 min
# 8764   2/15/2019          2015  TV-14  4 Seasons
# 8765    1/1/2016          1995   TV-G  2 Seasons
# 8766    8/1/2017          2016   TV-Y  3 Seasons
# 8767   9/15/2016          2014  TV-MA   1 Season
# 8768    4/1/2014          2012  TV-MA  8 Seasons
# 8769   3/31/2017          2016  TV-PG  2 Seasons
# 8770    5/5/2017          2016  TV-14   1 Season
# 8771   9/18/2017          2009  TV-14   1 Season
# 8772    1/1/2017          2012  TV-14   1 Season
# 8773  12/29/2018          2017  TV-PG  5 Seasons
# 8774    1/1/2017          2011  TV-14   1 Season
# 8775   3/31/2017          2015  TV-PG   1 Season
# 8776   3/31/2017          2013  TV-PG   1 Season
# 8777  12/15/2018          2016   TV-G   1 Season
# 8778    8/1/2017          2014  TV-MA   1 Season
# 8779   11/1/2016          2010  TV-14  3 Seasons
# 8780    2/1/2019          2017  TV-PG   1 Season
# 8781   8/31/2018          2018  TV-PG   1 Season
# 8782    4/1/2016          2015  TV-Y7   1 Season
# 8783   6/23/2018          2015   TV-Y     78 min
# 8784    5/1/2018          2015  TV-Y7  2 Seasons
# 8785   1/17/2017          2016  TV-PG  2 Seasons
# 8786   9/13/2018          2016  TV-Y7  3 Seasons
# 8787  12/15/2016          2012  TV-PG   1 Season
# 8788   6/23/2018          2016   TV-Y   1 Season
# 8789    6/7/2018          2016  TV-Y7   1 Season
#
#                                               listed_in
# 0                                         Documentaries
# 1     Crime TV Shows, International TV Shows, TV Act...
# 2                    TV Dramas, TV Horror, TV Mysteries
# 3                    Children & Family Movies, Comedies
# 4      Dramas, Independent Movies, International Movies
# 5                          British TV Shows, Reality TV
# 6                                      Comedies, Dramas
# 7     Children & Family Movies, Comedies, Music & Mu...
# 8                          Dramas, International Movies
# 9            Children & Family Movies, Music & Musicals
# 10                   Children & Family Movies, Comedies
# 11                   Children & Family Movies, Comedies
# 12       Dramas, International Movies, Music & Musicals
# 13                                               Movies
# 14                                               Movies
# 15                                               Movies
# 16                                             Comedies
# 17                               Docuseries, Reality TV
# 18         British TV Shows, Crime TV Shows, Docuseries
# 19                             Children & Family Movies
# 20                                             Kids' TV
# 21                                             Kids' TV
# 22                                             Kids' TV
# 23                             Children & Family Movies
# 24    Crime TV Shows, International TV Shows, TV Act...
# 25                  Documentaries, International Movies
# 26                             Children & Family Movies
# 27    Crime TV Shows, Docuseries, International TV S...
# 28                             Children & Family Movies
# 29      Comedies, International Movies, Romantic Movies
# ...                                                 ...
# 8760                  International TV Shows, TV Dramas
# 8761       Classic & Cult TV, Crime TV Shows, TV Dramas
# 8762                         British TV Shows, Kids' TV
# 8763                       Dramas, International Movies
# 8764  International TV Shows, Romantic TV Shows, TV ...
# 8765                                           Kids' TV
# 8766                          Kids' TV, Korean TV Shows
# 8767                 Docuseries, International TV Shows
# 8768                             TV Comedies, TV Dramas
# 8769  British TV Shows, Docuseries, Science & Nature TV
# 8770     International TV Shows, TV Comedies, TV Dramas
# 8771                  International TV Shows, TV Dramas
# 8772  International TV Shows, Romantic TV Shows, TV ...
# 8773                                          TV Dramas
# 8774  International TV Shows, Romantic TV Shows, TV ...
# 8775  British TV Shows, Docuseries, Science & Nature TV
# 8776  British TV Shows, Docuseries, Science & Nature TV
# 8777                                         Reality TV
# 8778    International TV Shows, TV Dramas, TV Thrillers
# 8779                         Crime TV Shows, Docuseries
# 8780                       British TV Shows, Docuseries
# 8781                International TV Shows, TV Comedies
# 8782                             Anime Series, Kids' TV
# 8783                           Children & Family Movies
# 8784                             Anime Series, Kids' TV
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# 8787  International TV Shows, Romantic TV Shows, TV ...
# 8788                                           Kids' TV
# 8789                                           Kids' TV
#
# [8790 rows x 10 columns]

# %% [markdown]
# #### psé, é bem melhor usar pandas.....
